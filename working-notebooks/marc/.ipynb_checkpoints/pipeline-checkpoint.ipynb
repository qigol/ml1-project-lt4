# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import html
import contractions
import nltk
import os

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

from sklearn.preprocessing import Normalizer
from sklearn.metrics.pairwise import euclidean_distances

import joblib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 5
#       3 import matplotlib.pyplot as plt
#       4 import html
# ----> 5 import contractions
#       6 import nltk
#       7 import os
#
# ModuleNotFoundError: No module named 'contractions'

# %%
# text preprocessing objects
svd_model = joblib.load('../../pickle-object/svd.pkl')
tfidf_vectorizer = joblib.load('../../pickle-object/tfidf.pkl')
final_n_svs = joblib.load('../../pickle-object/final_n_svs.pkl')

# model prediction objects
X_columns = joblib.load('../../pickle-object/X_columns.pkl')
model = joblib.load('../../pickle-object/model.pkl')

# for clustering
ref_df = pd.read_csv('cluster_reference_data.csv', index_col='Cluster_ID')

# %%
stop_words = set(stopwords.words("english"))
lemmatizer = WordNetLemmatizer()

def preprocess_nltk_alpha_only(text):
    text = html.unescape(str(text))
    text = contractions.fix(text)

    tokens = word_tokenize(text.lower())

    tokens = [
        lemmatizer.lemmatize(word)
        for word in tokens
        if word.isalpha() and word not in stop_words and len(word) > 2
    ]

    return " ".join(tokens)

# %%
def description_to_svd_vector(description):
    processed_text = preprocess_nltk_alpha_only(description)

    tfidf_vector = tfidf_vectorizer.transform([processed_text])

    svd_vector = svd_model.transform(tfidf_vector)[:, :final_n_svs]

    svd_vector_df = pd.DataFrame(
        svd_vector,
        columns=[f"SV_{i+1}" for i in range(final_n_svs)]
    )

    return svd_vector_df

# %%
svd_cols = [col for col in ref_df.columns if col.startswith('SV_')]
centroids_matrix = ref_df[svd_cols].values
competition_scores = ref_df['Competition_Score'].to_dict()

scaler = Normalizer(norm='l2')

def cluster(svd_vector_df):
    """Takes the SVD dataframe and instantly finds its market position."""
    
    new_scaled = scaler.transform(svd_vector_df.values)
    
    distances = euclidean_distances(new_scaled, centroids_matrix)[0]
    
    cluster = ref_df.index[np.argmin(distances)]
    competition_score = competition_scores[cluster]
    
    return cluster, competition_score

# %%
def predict_output(vec):
    return model.predict(pd.DataFrame(data=vec, columns=X_columns).fillna(0))

# %%
def run_pipeline(description=None, bin=False, bin_method=round):
    if description == None:
        description = input('Input game description: ')
        
    svd_df = description_to_svd_vector(description)

    predicted_score = predict_output(svd_df)
    if bin:
        predicted_score = bin_method(predicted_score[0])
    cluster, competition_score = cluster(svd_df)

    print(f"Predicted Score: {predicted_score}")
    print(f"Cluster: {cluster}, Competition Score: {competition_score}")

# %%
description = """
A board game so perfectly balanced between strategy, chaos, storytelling, and friendship that every group swears their playthrough was completely unique.

Set in a dying world lit by one final magical lantern, players take the roles of wandering factions trying to decide the future of civilization: preserve the light, monopolize it, destroy it, or discover what lies beyond the darkness. Every action permanently changes the board, the rules, and even the personalities of future characters.

Features include:

Fast turns with absurdly deep strategy.
Zero player elimination, everyone matters until the final second.
A diplomacy system where alliances naturally emerge without forced mechanics.
Combat that rewards creativity more than memorizing numbers.
Legacy elements without permanently destroying components.
Hidden objectives that evolve based on player behavior.
A soundtrack that somehow syncs perfectly with dramatic moments.
A rulebook people actually enjoy reading.

The game adapts to the group:

Competitive players discover brutal mind games.
Casual players accidentally create legendary stories.
Quiet players become masterminds.
Loud players become public enemies.

No dominant strategy has ever been found. Every “broken tactic” collapses once the table learns it. Games last anywhere from 45 minutes to 6 hours, yet somehow never feel too short or too long.

The ending is never just “who won.”
Instead, players finish by retelling the story of what happened:
the betrayal at the Glass Harbor, the impossible final stand at the Frost Gate, the merchant who accidentally became king, the moment everyone realized the quiet player had planned everything three hours earlier.

People don’t ask, “Want to play again?”
They ask, “Run it back.”
"""

run_pipeline(description, bin=True)
# Out:
# Predicted Score: 7
