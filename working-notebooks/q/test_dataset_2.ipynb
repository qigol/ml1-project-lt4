# %%
import pandas as pd

# %%
reviews = pd.read_csv("/mnt/data/public/bgg/bgg-15m-reviews.csv")
df = pd.read_csv('/mnt/data/public/bgg/games_detailed_info.csv')
test1 = pd.read_csv("/mnt/data/public/bgg/2022-01-08.csv")
# Out:
# /tmp/ipykernel_31350/436214862.py:2: DtypeWarning: Columns (29,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/mnt/data/public/bgg/games_detailed_info.csv')

# %% [markdown]
# boardgamecategory boardgamemechanic

# %%
test1.rename(columns={'Name':'name'}, inplace=True)
test1.rename(columns={'Users rated':'number_of_reviews'}, inplace=True)
df.rename(columns={'primary':'name'}, inplace=True)

# %%
new_df = test1.copy(deep=True)[['name']]
new_df = new_df.merge(df[['name','description', 'boardgamecategory', 'boardgamemechanic']], on='name', how='left')
new_df = new_df.merge(test1[['name','Average','number_of_reviews']], on='name', how='left')

# %%
new_df.dropna(inplace=True)
new_df.drop_duplicates(inplace=True)

# %%
new_df['class'] = new_df['Average'].apply(round)

# %%
df_balanced = new_df.groupby('class').sample(n=500, replace=True, random_state=42)

# %%
df_balanced.to_csv('../../data/new/balanced_bgg.csv')

# %%
df_balanced['

# %%
new_df.iloc[:10000, :].to_csv('../../data/boardgames_final.csv')

# %%
rpg_data = pd.read_csv("../../data/to_train.csv")

# %%
rpg_data['class'] = rpg_data['average_score'].apply(round)

# %%
rpg_df_balanced = rpg_data.groupby('class').sample(n=500, replace=True, random_state=42)

# %%
rpg_df_balanced['class'].value_counts()
# Out:
# class
# 1     500
# 2     500
# 3     500
# 4     500
# 5     500
# 6     500
# 7     500
# 8     500
# 9     500
# 10    500
# Name: count, dtype: int64

# %%
df_balanced['class'].value_counts()
# Out:
# class
# 1     500
# 2     500
# 3     500
# 4     500
# 5     500
# 6     500
# 7     500
# 8     500
# 9     500
# 10    500
# Name: count, dtype: int64

# %%
rpg_df_balanced
# Out:
#       Unnamed: 0                                 title  \
# 6115        6672                             Playelf 2
# 5015        5518                   deadEarth (1st Ed.)
# 8613        9487                     The Lost Universe
# 8557        9417                 Don't F*** the Priest
# 6154        6718                     Empire of Satanis
# ...          ...                                   ...
# 536          537     Moria: Through the Doors of Durin
# 1450        1598                        Hidden Kingdom
# 6213        6789  Fate of the Norns: Ragnarok (1st Ed)
# 8106        8871             Mörk Borg Character Sheet
# 8647        9539                          Stonewalkers
#
#                                             description  average_score  \
# 6115  A Swedish freeware RPG, available as a number ...           1.00
# 5015  user comment deadEarth is a game of survival s...           1.00
# 8613  From NASA: It’s time to gather your party and ...           1.00
# 8557  From the back of the box set: Filth, rot, deca...           1.00
# 6154  From the Game's Introduction: Empire of Satani...           1.00
# ...                                                 ...            ...
# 536   From the introduction: In days of old, Men and...           9.50
# 1450  User Summary/Game Materials: Hidden Kingdom is...          10.00
# 6213  from the first page of the book The Twilight o...           9.75
# 8106  Print-and-play character sheets are available ...          10.00
# 8647  From publisher blurb: Your path to Radiance be...          10.00
#
#       number_of_reviews   type  class
# 6115                  1  TTRPG      1
# 5015                  2  TTRPG      1
# 8613                  2  TTRPG      1
# 8557                  1  TTRPG      1
# 6154                  2  TTRPG      1
# ...                 ...    ...    ...
# 536                  18  TTRPG     10
# 1450                  3  TTRPG     10
# 6213                  4  TTRPG     10
# 8106                  1  TTRPG     10
# 8647                  1  TTRPG     10
#
# [5000 rows x 7 columns]

# %%
merged = df_balanced.merge(rpg_df_balanced, on='name', how='left')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 merged = df_balanced.merge(rpg_df_balanced, on='name', how='left')
#
# File ~/.conda/envs/lt4-major-project/lib/python3.12/site-packages/pandas/core/frame.py:10859, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10855         validate: MergeValidate | None = None,
#   10856     ) -> DataFrame:
#   10857         from pandas.core.reshape.merge import merge
#   10858
# > 10859         return merge(
#   10860             self,
#   10861             right,
#   10862             how=how,
#
# File ~/.conda/envs/lt4-major-project/lib/python3.12/site-packages/pandas/core/reshape/merge.py:170, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     155     return _cross_merge(
#     156         left_df,
#     157         right_df,
#    (...)    167         copy=copy,
#     168     )
#     169 else:
# --> 170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#     173         how=how,
#     174         on=on,
#     175         left_on=left_on,
#     176         right_on=right_on,
#     177         left_index=left_index,
#     178         right_index=right_index,
#     179         sort=sort,
#     180         suffixes=suffixes,
#     181         indicator=indicator,
#     182         validate=validate,
#     183     )
#     184     return op.get_result(copy=copy)
#
# File ~/.conda/envs/lt4-major-project/lib/python3.12/site-packages/pandas/core/reshape/merge.py:794, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     784     raise MergeError(msg)
#     786 self.left_on, self.right_on = self._validate_left_right_on(left_on, right_on)
#     788 (
#     789     self.left_join_keys,
#     790     self.right_join_keys,
#     791     self.join_names,
#     792     left_drop,
#     793     right_drop,
# --> 794 ) = self._get_merge_keys()
#     796 if left_drop:
#     797     self.left = self.left._drop_labels_or_levels(left_drop)
#
# File ~/.conda/envs/lt4-major-project/lib/python3.12/site-packages/pandas/core/reshape/merge.py:1298, in _MergeOperation._get_merge_keys(self)
#    1296 rk = cast(Hashable, rk)
#    1297 if rk is not None:
# -> 1298     right_keys.append(right._get_label_or_level_values(rk))
#    1299 else:
#    1300     # work-around for merge_asof(right_index=True)
#    1301     right_keys.append(right.index._values)
#
# File ~/.conda/envs/lt4-major-project/lib/python3.12/site-packages/pandas/core/generic.py:1914, in NDFrame._get_label_or_level_values(self, key, axis)
#    1910             values = self.xs(key, axis=other_axes[0])._values
#    1911         elif self._is_level_reference(key, axis=axis):
#    1912             values = self.axes[axis].get_level_values(key)._values
#    1913         else:
# -> 1914             raise KeyError(key)
#    1915
#    1916         # Check for duplicates
#    1917         if values.ndim > 1:
#
# KeyError: 'name'
