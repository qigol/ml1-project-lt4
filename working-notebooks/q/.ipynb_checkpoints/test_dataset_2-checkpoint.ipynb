# %%
import pandas as pd

# %%
reviews = pd.read_csv("/mnt/data/public/bgg/bgg-15m-reviews.csv")
df = pd.read_csv('/mnt/data/public/bgg/games_detailed_info.csv')
test1 = pd.read_csv("/mnt/data/public/bgg/2022-01-08.csv")
# Out:
# /tmp/ipykernel_31350/436214862.py:2: DtypeWarning: Columns (29,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/mnt/data/public/bgg/games_detailed_info.csv')

# %% [markdown]
# boardgamecategory boardgamemechanic

# %%
test1.rename(columns={'Name':'name'}, inplace=True)
test1.rename(columns={'Users rated':'number_of_reviews'}, inplace=True)
df.rename(columns={'primary':'name'}, inplace=True)

# %%
new_df = test1.copy(deep=True)[['name']]
new_df = new_df.merge(df[['name','description', 'boardgamecategory', 'boardgamemechanic']], on='name', how='left')
new_df = new_df.merge(test1[['name','Average','number_of_reviews']], on='name', how='left')

# %%
new_df.dropna(inplace=True)
new_df.drop_duplicates(inplace=True)

# %%
new_df['class'] = new_df['Average'].apply(round)

# %%
df_balanced = new_df.groupby('class').sample(n=500, replace=True, random_state=42)

# %%
df_balanced.to_csv('../../data/new/balanced_bgg.csv')

# %%
df_balanced['

# %%
new_df.iloc[:10000, :].to_csv('../../data/boardgames_final.csv')

# %%
rpg_data = pd.read_csv("../../data/to_train.csv")

# %%
rpg_data['class'] = rpg_data['average_score'].apply(round)

# %%
rpg_df_balanced = rpg_data.groupby('class').sample(n=500, replace=True, random_state=42)

# %%
rpg_df_balanced['class'].value_counts()
# Out:
# class
# 1     500
# 2     500
# 3     500
# 4     500
# 5     500
# 6     500
# 7     500
# 8     500
# 9     500
# 10    500
# Name: count, dtype: int64

# %%
df_balanced['class'].value_counts()
# Out:
# class
# 1     500
# 2     500
# 3     500
# 4     500
# 5     500
# 6     500
# 7     500
# 8     500
# 9     500
# 10    500
# Name: count, dtype: int64

# %%
rpg_df_balanced.rename(columns={'title':'name'}, inplace=True)

# %%
df_balanced.rename(columns={'Average':'average_score'}, inplace=True)

# %%
merged_df = pd.concat([df_balanced.loc[:, ['name','description','average_score','class']], rpg_df_balanced.loc[:, ['name','description','average_score','class']]], axis=0).reset_index(drop=True)

# %%
merged_df.iloc[:, :2].to_csv('../../data/new/balanced_desc_only.csv')

# %%
merged_df
# Out:
#                                       name  \
# 0                 Rock Paper Scissors Game
# 1              Oneupmanship: Mine's Bigger
# 2                 Rock Paper Scissors Game
# 3                 Rock Paper Scissors Game
# 4              Oneupmanship: Mine's Bigger
# ...                                    ...
# 9995     Moria: Through the Doors of Durin
# 9996                        Hidden Kingdom
# 9997  Fate of the Norns: Ragnarok (1st Ed)
# 9998             Mörk Borg Character Sheet
# 9999                          Stonewalkers
#
#                                             description  average_score  class
# 0     Pressman takes the classic game and puts it in...           1.31      1
# 1     &quot;Show me a good loser, and I'll show you ...           1.04      1
# 2     Pressman takes the classic game and puts it in...           1.31      1
# 3     Pressman takes the classic game and puts it in...           1.31      1
# 4     &quot;Show me a good loser, and I'll show you ...           1.04      1
# ...                                                 ...            ...    ...
# 9995  From the introduction: In days of old, Men and...           9.50     10
# 9996  User Summary/Game Materials: Hidden Kingdom is...          10.00     10
# 9997  from the first page of the book The Twilight o...           9.75     10
# 9998  Print-and-play character sheets are available ...          10.00     10
# 9999  From publisher blurb: Your path to Radiance be...          10.00     10
#
# [10000 rows x 4 columns]
