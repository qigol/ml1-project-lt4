# %%
import pandas as pd
import numpy as np

import pickle

from matplotlib import pyplot as plt

from tuner import Tuner

from sklearn.model_selection import train_test_split

from sklearn.neighbors import KNeighborsRegressor

from sklearn.metrics import accuracy_score, mean_absolute_error, mean_squared_error
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import r2_score

# %%
svd = pd.read_csv('../../pickle-object/balance_final_svd_table.csv')

# %%
X = svd.iloc[:, 4:]
y = svd['average_score']

# %%
tuner = Tuner(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
y_baseline = np.full_like(y, fill_value=np.mean(y))
rmse_baseline = np.sqrt(mean_squared_error(y, y_baseline))
rmse_baseline
# Out:
# np.float64(2.7413669012483934)

# %%
def bin_score(X, y, model, mapping_fn=round):
    """
    Evaluate a regression model, then bin outputs for classification-style accuracy.

    Parameters:
    -----------
    X : array-like
        Features
    y : array-like
        True continuous targets
    model : sklearn-like model
        Must implement .fit() and .predict()
    mapping_fn : function
        Function that maps continuous values → categorical bins
        Should work on numpy arrays

    Returns:
    --------
    dict with:
        - rmse
    """
    y_pred = model.predict(X)

    y_binned = y.apply(mapping_fn)
    y_pred_binned = pd.Series(y_pred).apply(mapping_fn)
    
    rmse = np.sqrt(mean_squared_error(y, y_pred))

    return float(rmse)

# %%
def build_conf_matrix(clf, X_test, y_test):
    y_pred = clf.predict(X_test)
    cm = confusion_matrix(round(y_test), round(pd.Series(data=y_pred)))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[i for i in range(1,11)])
    disp.plot(cmap=plt.cm.Blues)
    pass

# %%
def pred_actual(clf, X_text, y_test, bin=False):
    y_pred = clf.predict(X_test)
    
    if bin:
        y_test = round(pd.Series(data=y_test))
        y_pred = round(pd.Series(data=y_pred))

    r2 = r2_score(y_test, y_pred)
    
    plt.figure(figsize=(6, 6))
    plt.scatter(y_test, y_pred, color='blue', label='Predictions')
    
    max_val = max(max(y_test), max(y_pred))
    min_val = min(min(y_test), min(y_pred))
    plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--', label='Perfect Fit')
    
    plt.text(min_val, max_val, f'$R^2 = {r2:.3f}$', fontsize=12, verticalalignment='top')
    
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title('Predicted vs. Actual Plot')
    plt.legend()
    plt.grid(True)
    plt.show()

    pass

# %% [markdown]
# # KNN Regressor

# %%
tuner.tune(KNeighborsRegressor,
           10,
           0.25,
           'n_neighbors',
           range(1,15),
           {},
           bin_score,
           True
          )

# %%
tuner.results
# Out:
#        tune_id           classifier hyperparameter  \
# 0  17779855102  KNeighborsRegressor    n_neighbors
#
#    best_hyperparameter_setting  test_score  train_score
# 0                            2     0.46691     0.906025

# %%
tuner.plot_hyperparameter_tuning(17779855102, metric_name='rmse')

# %%
knn_reg = KNeighborsRegressor(n_neighbors=3)
knn_reg.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
build_conf_matrix(knn_reg, X_test, y_test)

# %%
pred_actual(knn_reg, X_test, y_test, False)

# %% [markdown]
# # Lasso and Ridge

# %%
from sklearn.linear_model import Lasso, Ridge

# %%
lasso_params = [1e-5, 1e-4, 1e-3,
                7e-3, 1e-2, 5e-2,
                0.1, 0.2, 0.4,
                0.75, 1, 1.5,
                3, 10, 20,
                100, 500]

# %%
tuner.tune(Lasso,
           10,
           0.25,
           'alpha',
           lasso_params,
           {'max_iter': 100000},
           bin_score,
           True)

# %%
tuner.tune(Ridge,
           10,
           0.25,
           'alpha',
           lasso_params,
           {'max_iter': 100000},
           bin_score,
           True)

# %%
tuner.results
# Out:
#        tune_id           classifier hyperparameter  \
# 0  17779855102  KNeighborsRegressor    n_neighbors
# 1  17779861469                Lasso          alpha
# 2  17779865874                Ridge          alpha
#
#    best_hyperparameter_setting  test_score  train_score
# 0                       2.0000    0.466910     0.906025
# 1                       0.0001    0.709631     0.981221
# 2                       0.4000    0.690674     0.960369

# %%
tuner.plot_hyperparameter_tuning(17779861469, True, metric_name='rmse')

# %%
lasso_reg = Lasso(alpha=0.0001)
lasso_reg.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.0001)

# %%
build_conf_matrix(lasso_reg, X_test, y_test)
# Out:
# 1.0525798626021974
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[142], line 1
# ----> 1 build_conf_matrix(lasso_reg, X_test, y_test)
#
# Cell In[141], line 6, in build_conf_matrix(clf, X_test, y_test)
#       2     y_pred = clf.predict(X_test)
#       3     cm = confusion_matrix(round(y_test), round(pd.Series(data=y_pred)))
#       4     print(y_pred.min())
#       5     disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[i for i in range(1,11)])
# ----> 6     disp.plot(cmap=plt.cm.Blues)
#       7     pass
#
# File ~/.conda/envs/lt4-major-project/lib/python3.12/site-packages/sklearn/metrics/_plot/confusion_matrix.py:188, in ConfusionMatrixDisplay.plot(self, include_values, cmap, xticks_rotation, values_format, ax, colorbar, im_kw, text_kw)
#     186 if colorbar:
#     187     fig.colorbar(self.im_, ax=ax)
# --> 188 ax.set(
#     189     xticks=np.arange(n_classes),
#     190     yticks=np.arange(n_classes),
#     191     xticklabels=display_labels,
#     192     yticklabels=display_labels,
#     193     ylabel="True label",
#     194     xlabel="Predicted label",
#     195 )
#     197 ax.set_ylim((n_classes - 0.5, -0.5))
#     198 plt.setp(ax.get_xticklabels(), rotation=xticks_rotation)
#
# File ~/.conda/envs/lt4-major-project/lib/python3.12/site-packages/matplotlib/artist.py:146, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     138 if not hasattr(cls.set, '_autogenerated_signature'):
#     139     # Don't overwrite cls.set if the subclass or one of its parents
#     140     # has defined a set method set itself.
#     141     # If there was no explicit definition, cls.set is inherited from
#     142     # the hierarchy of auto-generated set methods, which hold the
#     143     # flag _autogenerated_signature.
#     144     return
# --> 146 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     147 cls.set.__name__ = "set"
#     148 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File ~/.conda/envs/lt4-major-project/lib/python3.12/site-packages/matplotlib/artist.py:1241, in Artist.set(self, **kwargs)
#    1237 def set(self, **kwargs):
#    1238     # docstring and signature are auto-generated via
#    1239     # Artist._update_set_signature_and_docstring() at the end of the
#    1240     # module.
# -> 1241     return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#
# File ~/.conda/envs/lt4-major-project/lib/python3.12/site-packages/matplotlib/artist.py:1233, in Artist._internal_update(self, kwargs)
#    1226 def _internal_update(self, kwargs):
#    1227     """
#    1228     Update artist properties without prenormalizing them, but generating
#    1229     errors as if calling `set`.
#    1230
#    1231     The lack of prenormalization is to maintain backcompatibility.
#    1232     """
# -> 1233     return self._update_props(
#    1234         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1235         "{prop_name!r}")
#
# File ~/.conda/envs/lt4-major-project/lib/python3.12/site-packages/matplotlib/artist.py:1209, in Artist._update_props(self, props, errfmt)
#    1205             if not callable(func):
#    1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
# -> 1209             ret.append(func(v))
#    1210 if ret:
#    1211     self.pchanged()
#
# File ~/.conda/envs/lt4-major-project/lib/python3.12/site-packages/matplotlib/axes/_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File ~/.conda/envs/lt4-major-project/lib/python3.12/site-packages/matplotlib/axis.py:2106, in Axis.set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    2102 elif isinstance(locator, mticker.FixedLocator):
#    2103     # Passing [] as a list of labels is often used as a way to
#    2104     # remove all tick labels, so only error for > 0 labels
#    2105     if len(locator.locs) != len(labels) and len(labels) != 0:
# -> 2106         raise ValueError(
#    2107             "The number of FixedLocator locations"
#    2108             f" ({len(locator.locs)}), usually from a call to"
#    2109             " set_ticks, does not match"
#    2110             f" the number of labels ({len(labels)}).")
#    2111     tickd = {loc: lab for loc, lab in zip(locator.locs, labels)}
#    2112     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (11), usually from a call to set_ticks, does not match the number of labels (10).

# %%
pred_actual(lasso_reg, X_test, y_test, False)

# %%
tuner.plot_hyperparameter_tuning(17779865874, True, metric_name='rmse')

# %%
ridge_reg = Ridge(alpha=0.4000)
ridge_reg.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.4)

# %%
build_conf_matrix(ridge_reg, X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[156], line 1
# ----> 1 build_conf_matrix(ridge_reg, X_test, y_test)
#
# Cell In[143], line 5, in build_conf_matrix(clf, X_test, y_test)
#       1 def build_conf_matrix(clf, X_test, y_test):
#       2     y_pred = clf.predict(X_test)
#       3     cm = confusion_matrix(round(y_test), round(pd.Series(data=y_pred)))
#       4     disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[i for i in range(1,11)])
# ----> 5     disp.plot(cmap=plt.cm.Blues)
#       6     pass
#
# File ~/.conda/envs/lt4-major-project/lib/python3.12/site-packages/sklearn/metrics/_plot/confusion_matrix.py:188, in ConfusionMatrixDisplay.plot(self, include_values, cmap, xticks_rotation, values_format, ax, colorbar, im_kw, text_kw)
#     186 if colorbar:
#     187     fig.colorbar(self.im_, ax=ax)
# --> 188 ax.set(
#     189     xticks=np.arange(n_classes),
#     190     yticks=np.arange(n_classes),
#     191     xticklabels=display_labels,
#     192     yticklabels=display_labels,
#     193     ylabel="True label",
#     194     xlabel="Predicted label",
#     195 )
#     197 ax.set_ylim((n_classes - 0.5, -0.5))
#     198 plt.setp(ax.get_xticklabels(), rotation=xticks_rotation)
#
# File ~/.conda/envs/lt4-major-project/lib/python3.12/site-packages/matplotlib/artist.py:146, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     138 if not hasattr(cls.set, '_autogenerated_signature'):
#     139     # Don't overwrite cls.set if the subclass or one of its parents
#     140     # has defined a set method set itself.
#     141     # If there was no explicit definition, cls.set is inherited from
#     142     # the hierarchy of auto-generated set methods, which hold the
#     143     # flag _autogenerated_signature.
#     144     return
# --> 146 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     147 cls.set.__name__ = "set"
#     148 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File ~/.conda/envs/lt4-major-project/lib/python3.12/site-packages/matplotlib/artist.py:1241, in Artist.set(self, **kwargs)
#    1237 def set(self, **kwargs):
#    1238     # docstring and signature are auto-generated via
#    1239     # Artist._update_set_signature_and_docstring() at the end of the
#    1240     # module.
# -> 1241     return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#
# File ~/.conda/envs/lt4-major-project/lib/python3.12/site-packages/matplotlib/artist.py:1233, in Artist._internal_update(self, kwargs)
#    1226 def _internal_update(self, kwargs):
#    1227     """
#    1228     Update artist properties without prenormalizing them, but generating
#    1229     errors as if calling `set`.
#    1230
#    1231     The lack of prenormalization is to maintain backcompatibility.
#    1232     """
# -> 1233     return self._update_props(
#    1234         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1235         "{prop_name!r}")
#
# File ~/.conda/envs/lt4-major-project/lib/python3.12/site-packages/matplotlib/artist.py:1209, in Artist._update_props(self, props, errfmt)
#    1205             if not callable(func):
#    1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
# -> 1209             ret.append(func(v))
#    1210 if ret:
#    1211     self.pchanged()
#
# File ~/.conda/envs/lt4-major-project/lib/python3.12/site-packages/matplotlib/axes/_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File ~/.conda/envs/lt4-major-project/lib/python3.12/site-packages/matplotlib/axis.py:2106, in Axis.set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    2102 elif isinstance(locator, mticker.FixedLocator):
#    2103     # Passing [] as a list of labels is often used as a way to
#    2104     # remove all tick labels, so only error for > 0 labels
#    2105     if len(locator.locs) != len(labels) and len(labels) != 0:
# -> 2106         raise ValueError(
#    2107             "The number of FixedLocator locations"
#    2108             f" ({len(locator.locs)}), usually from a call to"
#    2109             " set_ticks, does not match"
#    2110             f" the number of labels ({len(labels)}).")
#    2111     tickd = {loc: lab for loc, lab in zip(locator.locs, labels)}
#    2112     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (11), usually from a call to set_ticks, does not match the number of labels (10).

# %%
pred_actual(ridge_reg, X_test, y_test, False)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr_settings = {}

# %%
tuner.tune(RandomForestRegressor,
           10,
           0.25,
           'max_depth',
           range(2,6),
           {'random_state': 42},
           bin_score,
           True)

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
tuner.tune(GradientBoostingRegressor,
           10,
           0.25,
           'max_depth',
           range(2,6),
           {'random_state': 42},
           bin_score,
           True)

# %%
g_boost = GradientBoostingRegressor(max_depth=1)
g_boost.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(max_depth=1)

# %%
build_conf_matrix(g_boost, X_test, y_test)

# %%
pred_actual(g_boost, X_test, y_test, False)

# %%
tuner.results
# Out:
#        tune_id                 classifier hyperparameter  \
# 0  17779855102        KNeighborsRegressor    n_neighbors
# 1  17779861469                      Lasso          alpha
# 2  17779865874                      Ridge          alpha
# 3  17780029002  GradientBoostingRegressor      max_depth
#
#    best_hyperparameter_setting  test_score  train_score
# 0                       2.0000    0.466910     0.906025
# 1                       0.0001    0.709631     0.981221
# 2                       0.4000    0.690674     0.960369
# 3                       5.0000    0.504355     0.824458

# %%
tuner.plot_hyperparameter_tuning(17779454294, metric_name='max_depth')

# %%
tuner.tune(GradientBoostingRegressor,
           10,
           0.25,
           'learning_rate',
           [1e-3, 1e-2, 1e-1],
           {'random_state': 42, 'max_depth': 5},
           bin_score,
           True)
