# %%
from imblearn.over_sampling import SMOTE

import pandas as pd
import numpy as np

# %%
svd = pd.read_csv('../../pickle-object/final_svd_table.csv')

# %%
X = svd.iloc[:, 4:]
y = round(svd['average_score'])

# %%
X_sample = np.array(X.iloc[:1000, :])
y_sample = np.array(y.iloc[:1000].astype(int))

# %%
sm = SMOTE(random_state=42)

# %%
X_res, y_res = sm.fit_resample(X, y)

# %%
sm.fit(X, y)
# Out:
# SMOTE(random_state=42)

# %%
from sklearn.datasets import make_classification

X_test, y_test = make_classification(n_classes=2, class_sep=2,
weights=[0.1, 0.9], n_informative=3, n_redundant=1, flip_y=0,
n_features=20, n_clusters_per_class=1, n_samples=1000, random_state=10)

# %%
X_res, y_res = sm.fit_resample(X_test, y_test)

# %%
y_sample[y_sample==1]
# Out:
# array([], dtype=int64)

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
ros = RandomOverSampler(random_state=42)
X_res, y_res = ros.fit_resample(X, y)
