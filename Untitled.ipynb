# %%
import gdown

# %%
svd_pickle = 'https://drive.google.com/file/d/1Rif_Dy46Rfla3ZDTiiHIsvd9WDT75EGe/view?usp=drive_link'
svd_output = 'pickle-object/final_svd_objects.pkl'

# %%
svd_complete = 'https://drive.google.com/file/d/1wdMHtS6pl_t-HqfyfFi05RqEN-d42Q6s/view?usp=drive_link'
svd__complete_output = 'pickle-object/final_svd_table.csv'

# %%
gdown.download(svd_complete, svd__complete_output, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1wdMHtS6pl_t-HqfyfFi05RqEN-d42Q6s
# From (redirected): https://drive.google.com/uc?id=1wdMHtS6pl_t-HqfyfFi05RqEN-d42Q6s&confirm=t&uuid=f8f9ed5b-856b-4f9f-8a5e-7406b01577e3
# To: /home/bsdsba2028/qangos/ml1-project-lt4/pickle-object/final_svd_table.csv
# 100%|██████████| 1.24G/1.24G [00:27<00:00, 45.6MB/s]
# 'pickle-object/final_svd_table.csv'
