# %%
import gdown

# %%
svd_pickle = 'https://drive.google.com/file/d/1Rif_Dy46Rfla3ZDTiiHIsvd9WDT75EGe/view?usp=drive_link'
svd_output = 'pickle-object/final_svd_objects.pkl'

# %%
svd_complete = 'https://drive.google.com/file/d/1wdMHtS6pl_t-HqfyfFi05RqEN-d42Q6s/view?usp=drive_link'
svd__complete_output = 'pickle-object/final_svd_table.csv'

# %%
svd_balance = 'https://drive.google.com/file/d/1qljvIGWds1eL16qiJ8JMllgwV8Uy-8LH/view?usp=drive_link'
svd_balance_output = 'pickle-object/balance_final_svd_table_all.csv'

# %%
clusters = 'https://drive.google.com/file/d/1PlwaJOX76d8FaniNUCY_k8FMEj6lFS_0/view?usp=drive_link'
clusters_output = 'pickle-object/clusters.csv'

# %%
gdown.download(clusters, clusters_output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1PlwaJOX76d8FaniNUCY_k8FMEj6lFS_0
# To: /home/bsdsba2028/qangos/ml1-project-lt4/pickle-object/clusters.csv
# 100%|██████████| 1.36M/1.36M [00:00<00:00, 10.6MB/s]
# 'pickle-object/clusters.csv'
