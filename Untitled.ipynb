# %%
import gdown

# %%
svd_pickle = 'https://drive.google.com/file/d/1Rif_Dy46Rfla3ZDTiiHIsvd9WDT75EGe/view?usp=drive_link'
svd_output = 'pickle-object/final_svd_objects.pkl'

# %%
svd_complete = 'https://drive.google.com/file/d/1wdMHtS6pl_t-HqfyfFi05RqEN-d42Q6s/view?usp=drive_link'
svd__complete_output = 'pickle-object/final_svd_table.csv'

# %%
svd_balance = 'https://drive.google.com/file/d/1i1qukPzQyK58E3Jfv9jStnlY8WhULfQG/view?usp=drive_link'
svd_balance_output = 'pickle-object/balance_final_svd_table.csv'

# %%
gdown.download(svd_balance, svd_balance_output, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1i1qukPzQyK58E3Jfv9jStnlY8WhULfQG
# From (redirected): https://drive.google.com/uc?id=1i1qukPzQyK58E3Jfv9jStnlY8WhULfQG&confirm=t&uuid=6fc0e078-93ee-4e42-b193-ace2bb630a68
# To: /home/bsdsba2028/qangos/ml1-project-lt4/pickle-object/balance_final_svd_table.csv
# 100%|██████████| 140M/140M [00:13<00:00, 10.2MB/s]
# 'pickle-object/balance_final_svd_table.csv'
